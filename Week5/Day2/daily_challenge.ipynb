# %% [markdown]
# Load and Visualize Images using the Flower Color Images dataset
# Rotate an image by 90 degrees
# Flip an image horizontally and then vertically.
# Zoom in on an image (scale by 1.2x) using .resize(...)
# Display the original and augmented images side by side for comparison using this function :
# import matplotlib.pyplot as plt
# from PIL import Image, ImageOps
#
# def show_images(original, augmented, title):
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.imshow(original)
# plt.title('Original Image')
# plt.axis('off')
#
# plt.subplot(1, 2, 2)
# plt.imshow(augmented)
# plt.title(title)
# plt.axis('off')
#
# plt.show()

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 10.1 MB/s eta 0:00:00 0:00:010m
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.9/245.9 kB 18.2 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.9 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/ilyagelfgat/Documents/DI_Bootcamp/Week3/Day4/my_postgres/lib/python3.11/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ilyagelfgat/Documents/DI_Bootcamp/Week3/Day4/my_postgres/lib/python3.11/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 34.2 MB/s eta 0:00:00a 0:00:01
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ilyagelfgat/Documents/DI_Bootcamp/Week3/Day4/my_postgres/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/ilyagelfgat/Documents/DI_Bootcamp/Week3/Day4/my_postgres/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# Function to display images side by side
def show_images(original, augmented, title):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(original)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(augmented)
    plt.title(title)
    plt.axis('off')

    plt.show()

image_path = '/Users/ilyagelfgat/Documents/DI_Bootcamp/Week5/Day2/archive-3/flower_images/flower_images/0001.png'
original_image = Image.open(image_path)

rotated_image = original_image.rotate(90, expand=True)
show_images(original_image, rotated_image, 'Rotated Image (90 degrees)')

flipped_horizontally = ImageOps.mirror(original_image)
show_images(original_image, flipped_horizontally, 'Horizontally Flipped Image')

flipped_vertically = ImageOps.flip(original_image)
show_images(original_image, flipped_vertically, 'Vertically Flipped Image')

width, height = original_image.size
zoomed_image = original_image.resize((int(width * 1.2), int(height * 1.2)))
show_images(original_image, zoomed_image, 'Zoomed Image (1.2x)')
