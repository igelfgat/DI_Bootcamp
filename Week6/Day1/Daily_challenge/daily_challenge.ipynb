# %%
import pandas as pd 
df_2015 = pd.read_csv('2015.csv')
df_2016 = pd.read_csv('2016.csv')
df_2017 = pd.read_csv('2017.csv')
df_2018 = pd.read_csv('2018.csv')
df_2019 = pd.read_csv('2019.csv')

print(df_2019.info())
print(df_2019.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
# None
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# ...

# %%
df_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df_2019['Score'], df_2019['Social support'])
plt.title("Social support across Score Scatter Plot")
plt.xlabel("Score")
plt.ylabel("Social support")
plt.show()

# %%
fig, axs = plt.subplots(2, 1, figsize=(20, 20))

# Plot GDP per Capita
axs[0].scatter(df_2019['Country or region'], df_2019['GDP per capita'], color='blue')
axs[0].set_title('GDP per Capita across Countries')
axs[0].set_xlabel('Country')
axs[0].set_ylabel('GDP per Capita')
axs[0].tick_params(axis='x', rotation=90)

# Plot Healthy Life Expectancy
axs[1].scatter(df_2019['Country or region'], df_2019['Healthy life expectancy'], color='green')
axs[1].set_title('Healthy Life Expectancy across Countries')
axs[1].set_xlabel('Country')
axs[1].set_ylabel('Healthy Life Expectancy')
axs[1].tick_params(axis='x', rotation=90)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(20, 15))

# Bar plot for GDP per Capita
ax1.bar(df_2019['Country or region'], df_2019['GDP per capita'], color='blue', alpha=0.6, label='GDP per Capita')
ax1.set_xlabel('Country or region')
ax1.set_ylabel('GDP per capita', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.tick_params(axis='x', rotation=90)

# Create a secondary y-axis for Healthy Life Expectancy
ax2 = ax1.twinx()
ax2.plot(df_2019['Country or region'], df_2019['Healthy life expectancy'], color='green', marker='o', label='Healthy Life Expectancy')
ax2.set_ylabel('Healthy life expectancy', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Add titles and legends
plt.title('GDP per Capita and Healthy Life Expectancy across Countries')
fig.tight_layout()
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
