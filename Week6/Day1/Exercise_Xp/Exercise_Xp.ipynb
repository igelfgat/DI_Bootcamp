# %% [markdown]
# Exercise 1 : Understanding Data Visualization
#
# Instructions
#
# Explain why data visualization is important in data analysis.
# Describe the purpose of a line graph in data visualization.

# %% [markdown]
# 1)Data visualization is important in data analysis because it helps to simplify complex data sets
# 2)The purpose of a line graph is to show how a variable changes over time, allowing for the visualization of trends, comparisons between different data sets, and the identification of any fluctuations or patterns.

# %% [markdown]
# Exercise 2 : Creating A Line Plot For Temperature Variation
#
# Instructions
#
# Create a simple line plot using Matplotlib that represents the temperature variations over a week.
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.

# %%
import matplotlib.pyplot as plt

temperatures = [72, 74, 76, 80, 82, 78, 75]
days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]

plt.figure()
plt.plot(days, temperatures, marker='o')

plt.xlabel("Day")
plt.ylabel("Temperature (°F)")

plt.title("Temperature Variation Over a Week")

plt.show()

# %% [markdown]
#  Exercise 3 : Visualizing Monthly Sales With A Bar Chart
#
# Instructions
#
# Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.

# %%
sales_amount = [5000, 5500, 6200, 7000, 7500]
month = ["June", "July", "August", "September", "October"]

plt.figure()
plt.plot(month, sales_amount, marker='o')

plt.ylabel("Sales Amount ($)")
plt.xlabel("Month")

plt.title("Monthly Sales")

plt.show()

# %% [markdown]
# Exercise 4 : Data Visualisation
#
# Instructions
#
# Using the dataset sales_data.csv
#
# Calculate the total quantity of products sold by the company.
# Identify the category that had the highest revenue and calculate how much revenue it generated.
# Determine the average revenue per sale in the dataset.
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
import pandas as pd
sales_data = pd.read_csv('sales_data.csv')
sales_data
# Out:
#            date     product     category   price  quantity  revenue
# 0    2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1    2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2    2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3    2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4    2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ..          ...         ...          ...     ...       ...      ...
# 364  2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [369 rows x 6 columns]

# %%
total_quantity = sales_data['quantity'].sum()
total_quantity
# Out:
# 5360.0

# %%
sales_data['category'] = sales_data['category'].replace(['Shoeses', 'Shoes'], 'Shoes')
sales_data['category'] = sales_data['category'].replace(['Clohting', 'Clothing'], 'Clothing')
sales_data['category'] = sales_data['category'].replace(['Bags', 'Bgas'], 'Bags')

# %%
sales_data['revenue'] = sales_data['price'] * sales_data['quantity']
category_revenue = sales_data.groupby('category')['revenue'].sum()
category_revenue
# Out:
# category
# Accessories    103400.0
# Bags            20400.0
# Clothing        95550.0
# Electronics    509480.0
# Shoes           21600.0
# Name: revenue, dtype: float64

# %%
highest_revenue_category = category_revenue.idxmax()
highest_revenue_amount = category_revenue.max()
print(f"Category with the highest revenue: {highest_revenue_category} ({highest_revenue_amount})")
# Out:
# Category with the highest revenue: Electronics (509480.0)

# %%
avg_rev_sale = sales_data['revenue'].sum()/sales_data['quantity'].sum()
print(avg_rev_sale)
# Out:
# 141.4794776119403

# %%
sales_data['date'] = pd.to_datetime(sales_data['date'])

sales_data['quarter'] = sales_data['date'].dt.to_period('Q')

quarterly_revenue = sales_data.groupby('quarter')['revenue'].sum()

plt.figure()
quarterly_revenue.plot(kind='bar')
plt.xlabel('Quarter')
plt.ylabel('Total Revenue')
plt.title('Total revenue generated in each quarter')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Exercise 5 : Data Visualisation Using MatPlotLib
#
# Instructions
#
# Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.
# Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.
# Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %%
x = range(-10, 11)
y = [i**2 for i in x]
plt.figure()

plt.plot(x, y, marker='o')

plt.xlabel("x")
plt.ylabel("y")

plt.title("Number squared")
# Out:
# Text(0.5, 1.0, 'Number squared')

# %%
products = ['A', 'B', 'C', 'D']
sales_values = [15, 30, 45, 20]

plt.figure()
plt.bar(products, sales_values, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Sales Data of Four Different Products in a Week')
plt.show()

# %%
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
percentages = [40, 30, 20, 10]
colors = ['red', 'yellow', 'pink', 'brown']

plt.figure(figsize=(9, 7))
plt.pie(percentages, labels=fruits, colors=colors)
plt.title('Favorite Fruits of a Group of People')
plt.legend(fruits)
plt.show()
