# %% [markdown]
# 1. Data Preparation:
#
# Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
# Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.
#
# Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
#
# Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.

# %%
import numpy as np
import pandas as pd
from faker import Faker
fake = Faker()
num_cities = 10
num_months = 12
temperature_data = np.random.uniform(low=-5, high=35, size=(num_cities, num_months))

cities = [fake.city() for _ in range(num_cities)]
months = ['January', 'February', 'March', 'April', 'May', 'June', 
          'July', 'August', 'September', 'October', 'November', 'December']

temperature_df = pd.DataFrame(data=temperature_data, index=cities, columns=months)
temperature_df
# Out:
#                    January   February      March      April        May  \
# South William    24.910581  18.767124   8.178401  20.005689  10.241363
# West Susanland   22.304258  -2.023982  -0.752313  -1.905392  -3.252068
# Lake Kathryn      4.763028  25.933730  23.374370  33.656063  -2.841963
# East Janetland   11.812072  17.210147  25.186446  22.444969  14.910466
# West Ralph        6.582581   1.695742   8.268176  -0.158773  21.300948
# Lake Jessica     20.619662  26.921133   0.357947  12.222811  17.890370
# New Angela        7.789123  28.040225  10.691781  12.235606   2.419582
# Jacobstad        -2.606219  30.276105  25.200096   3.378831  17.332306
# Sanchezland      14.893848  20.771216  -4.926595  -3.380724  -0.922034
# Harringtonmouth  17.972861  24.556498   8.417907  21.997395   5.082780
#
#                       June       July     August  September    October  \
# South William    15.114358  16.507931  32.777453  34.487313  25.909707
# West Susanland    0.282819  11.188621   1.709372  18.290843  29.823710
# Lake Kathryn      9.919762  -0.587228  -2.458601   6.208772  24.737530
# East Janetland    3.160573  16.377435   9.158329  10.130292  21.725497
# West Ralph       30.125259  29.594909   6.198386  14.965407  18.734437
# Lake Jessica      5.182073  24.789026  17.550801  26.383782  23.085630
# New Angela       21.838665   8.121878  23.673996   7.791552   9.180234
# Jacobstad        31.022467   9.258678  -1.869632  -2.460767  27.671572
# Sanchezland       9.035983  32.077028  27.858266   5.788025  30.878825
# Harringtonmouth   2.411857  12.273561  18.584030  13.242381  19.724685
#
#                   November   December
# South William    29.876073   5.243105
# West Susanland   -2.240471  25.513734
# Lake Kathryn     20.631076  23.658297
# East Janetland   -4.555310   1.542366
# West Ralph       30.014868  12.952520
# Lake Jessica     15.207142  31.782625
# New Angela       15.898016  31.172961
# Jacobstad        -3.081687  33.310833
# Sanchezland      31.682605  10.028522
# Harringtonmouth  18.841566  16.185016

# %% [markdown]
# 2. Data Analysis:
#
# Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
# Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.
#
# Calculate the annual average temperature for each city.
#
# Identify the city with the highest and lowest average temperature for the year.

# %%
annual_avg_temp = temperature_df.mean(axis=1)
annual_avg_temp
# Out:
# South William      20.168258
# West Susanland      8.244928
# Lake Kathryn       13.916236
# East Janetland     12.425273
# West Ralph         15.022872
# Lake Jessica       18.499417
# New Angela         14.904468
# Jacobstad          13.952715
# Sanchezland        14.482080
# Harringtonmouth    14.940878
# dtype: float64

# %%
city_highest_avg_temp = annual_avg_temp.idxmax()
city_lowest_avg_temp = annual_avg_temp.idxmin()
print(city_highest_avg_temp)
print(city_lowest_avg_temp)
# Out:
# South William
# West Susanland

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
for city in cities:
    plt.plot(months, temperature_df.loc[city], marker='o', label=city)

plt.xlabel('Month')
plt.ylabel('Average Temperature (°C)')
plt.title('Monthly Average Temperature for Each City')
plt.xticks(rotation=45, ha='right')

plt.grid(which='both', axis='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.show()
