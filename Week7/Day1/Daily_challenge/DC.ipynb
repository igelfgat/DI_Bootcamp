# %% [markdown]
# 1. Data Preparation:
#
# Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
# Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.
#
# Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
#
# Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.

# %%
import numpy as np
import pandas as pd
from faker import Faker
fake = Faker()
num_cities = 10
num_months = 12
temperature_data = np.random.uniform(low=-5, high=35, size=(num_cities, num_months))

cities = [fake.city() for _ in range(num_cities)]
months = ['January', 'February', 'March', 'April', 'May', 'June', 
          'July', 'August', 'September', 'October', 'November', 'December']

temperature_df = pd.DataFrame(data=temperature_data, index=cities, columns=months)
print(temperature_df)
# Out:
#                      January   February      March      April        May  \
# Mcdonaldland        1.738248  14.722774  23.744401  15.977493  12.068593
# Lake Tamara        -3.292972   4.877971  10.118532  12.784460  22.753882
# Lynntown           18.333866  12.978842  22.994459  -0.707803   2.699784
# New Laurastad      21.367025  19.758024  13.176027  -2.088794   5.873726
# Brownside          10.895615  24.708235  23.447681  12.176415   1.960425
# East Joshuaside     9.815733  -2.235682  31.338025  30.331837  32.933059
# Port Mary           7.349700  16.054626  26.423499  -1.861790  17.408887
# Tonyton             1.328541   1.032982  21.959747  -1.432451  -4.511621
# South Michaelview  19.801932   1.197177  29.566320  30.630900  28.469691
# Andrewhaven        -1.914253   9.987401   7.833653   0.877946  16.696190
#
#                         June       July     August  September    October  \
# Mcdonaldland       25.216840  29.162192  22.545487  28.569128  31.261756
# Lake Tamara        16.488587  23.332739  27.263107  23.503736  30.848163
# Lynntown           31.336348   0.892541  33.126353  29.707240  12.981346
# New Laurastad      31.161853  31.822680   4.546836   8.594330  30.084577
# Brownside          13.667429   9.088477   2.908981  21.123659  18.653428
# East Joshuaside     0.398549   4.441244  34.034060   7.626239   8.176284
# Port Mary          30.621694   8.360691  25.484188  -1.053754  25.970762
# Tonyton            16.971969  11.060808  24.302303   1.833750  24.342906
# South Michaelview   4.224966  11.803059  10.302315  -1.623296   2.119502
# Andrewhaven        -2.760501  23.386227  32.405273  23.515875   2.824032
#
#                     November   December
# Mcdonaldland       28.397314  33.071941
# Lake Tamara        13.343844  25.935916
# Lynntown           23.302039  14.047555
# New Laurastad      20.212399  12.130866
# Brownside          32.101988  33.718967
# East Joshuaside     8.226070   3.578519
# Port Mary           5.797952  27.126265
# Tonyton             4.101853  18.449006
# South Michaelview   5.991874  23.720502
# Andrewhaven        13.432441  21.849297

# %% [markdown]
# 2. Data Analysis:
#
# Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
# Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.
#
# Calculate the annual average temperature for each city.
#
# Identify the city with the highest and lowest average temperature for the year.

# %%
annual_avg_temp = temperature_df.mean(axis=1)
annual_avg_temp
# Out:
# Mcdonaldland         22.206347
# Lake Tamara          17.329830
# Lynntown             16.807714
# New Laurastad        16.386629
# Brownside            17.037608
# East Joshuaside      14.055328
# Port Mary            15.640227
# Tonyton               9.953316
# South Michaelview    13.850412
# Andrewhaven          12.344465
# dtype: float64

# %%
city_highest_avg_temp = annual_avg_temp.idxmax()
city_lowest_avg_temp = annual_avg_temp.idxmin()
print(city_highest_avg_temp)
print(city_lowest_avg_temp)
# Out:
# Mcdonaldland
# Tonyton

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
for city in cities:
    plt.plot(months, temperature_df.loc[city], marker='o', label=city)

plt.xlabel('Month')
plt.ylabel('Average Temperature (°C)')
plt.title('Monthly Average Temperature for Each City')
plt.xticks(rotation=45, ha='right')

plt.grid(which='both', axis='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.show()
