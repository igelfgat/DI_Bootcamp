# %% [markdown]
# Exercise 1 : Basic Usage Of SciPy
#
# Instructions
#
# Import the SciPy library and explore its version.

# %%
import scipy
import scipy.stats as stats
import numpy as np
scipy.__version__
# Out:
# '1.11.1'

# %% [markdown]
# 🌟 Exercise 2 : Descriptive Statistics
#
# Instructions
#
# Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample dataset in code:
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
data = [12, 15, 13, 12, 18, 20, 22, 21]
mean_scipy = stats.tmean(data)
median_scipy = np.median(data)  # SciPy does not have a separate median function
variance_scipy = stats.tvar(data)
std_dev_scipy = stats.tstd(data)
mean_scipy, median_scipy, variance_scipy, std_dev_scipy
# Out:
# (16.625, 16.5, 17.125, 4.138236339311712)

# %% [markdown]
#  Exercise 3 : Understanding Distributions
#
# Instructions
#
# Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 50
std_dev = 10

# Generate the normal distribution
# Using linspace to cover the range from mean - 4*std_dev to mean + 4*std_dev
data = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)
pdf = norm.pdf(data, mean, std_dev)

plt.figure(figsize=(10, 6))
plt.plot(data, pdf, label=f'Normal Distribution (mean={mean}, std={std_dev})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Normal Distribution')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
#  Exercise 4 : T-Test Application
#
# Instructions
#
# Perform a T-test on two sets of randomly generated data. Hint: Use numpy.random.normal() to generate the datasets.

# %%
mean1, std_dev1, size1 = 50, 10, 100 
mean2, std_dev2, size2 = 55, 12, 100 

data1 = np.random.normal(loc=mean1, scale=std_dev1, size=size1)
data2 = np.random.normal(loc=mean2, scale=std_dev2, size=size2)

t_stat, p_value = stats.ttest_ind(data1, data2)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("The difference between the two datasets is statistically significant.")
else:
    print("There is no significant difference between the two datasets.")
# Out:
# T-statistic: -2.6198
# P-value: 0.0095
# The difference between the two datasets is statistically significant.

# %% [markdown]
# Exercise 5 : Working With DataFrames
#
# Instructions
#
# Task: Import a dataset using Pandas and calculate descriptive statistics for a specific column using SciPy.
#
# Sample Dataset: Use any publicly available dataset (e.g., Iris dataset).

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
mean_scipy = stats.tmean(df['SepalLengthCm'])
median_scipy = np.median(df['SepalLengthCm'])  # SciPy does not have a separate median function
variance_scipy = stats.tvar(df['SepalLengthCm'])
std_dev_scipy = stats.tstd(df['SepalLengthCm'])
mean_scipy, median_scipy, variance_scipy, std_dev_scipy
# Out:
# (5.843333333333334, 5.8, 0.6856935123042507, 0.828066127977863)

# %% [markdown]
# Exercise 6 : Advanced Statistical Functions
#
# Instructions
#
# Task: Explore one advanced statistical function in SciPy and demonstrate its use with an example.
#
# Sample Task: Calculate kurtosis and skewness of a dataset.

# %%
data = np.random.normal(0, 1, 1000)
skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)
skewness, kurtosis
# Out:
# (-0.09470982809226908, -0.014415674829458158)
