# %% [markdown]
# Objective: Implement linear regression on a new dataset and interpret the results.
#
# Instructions:
#
# 1. Use the following dataset: x = np.array([2, 4, 6, 8, 10])`, `y = np.array([3, 5, 7, 9, 11]).
#
# 2. Apply linear regression using SciPy to find the slope and intercept.
#
# 3. Plot the data points and the regression line.
#
# 4. Interpret the slope and intercept in the context of this data.

# %%
import numpy as np
from scipy import stats
x = np.array([2, 4, 6, 8, 10])
y = np.array([3, 5, 7, 9, 11])

# %%
# Performing linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# The slope and intercept of the regression line
print("Slope:", slope)
print("Intercept:", intercept)
# Out:
# Slope: 1.0
# Intercept: 1.0

# %%
import matplotlib.pyplot as plt
# Generate regression line values
y_pred = slope * x + intercept # y = mx + b ## m-slope, b-intercept
print(y_pred)
# Plot data points and regression line
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.title('Linear Regression Analysis')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [ 3.  5.  7.  9. 11.]

# %%
# Interpretation
print(f"Interpretation:")
print(f"The slope of the regression line is {slope:.2f}. This means that for each unit increase in x, y increases by {slope:.2f}.")
print(f"The intercept of the regression line is {intercept:.2f}. This means that when x is 0, the expected value of y is {intercept:.2f}.")
# Out:
# Interpretation:
# The slope of the regression line is 1.00. This means that for each unit increase in x, y increases by 1.00.
# The intercept of the regression line is 1.00. This means that when x is 0, the expected value of y is 1.00.

# %% [markdown]
# Exercise 2: ANOVA Interpretation
#
# Scenario: An ANOVA test was conducted to compare the effectiveness of three different diets. The F-value obtained was 9.7, and the P-value was 0.001.
#
# Questions:
#
# 1. Explain what the F-value and P-value indicate in this context.
#
# 2. Based on these values, what conclusion can you draw about the effectiveness of the diets?
